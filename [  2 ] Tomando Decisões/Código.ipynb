# %% [markdown]
# <a href="https://colab.research.google.com/github/Assaoka/Decolar--Introducao_a_Ciencia_de_Dados/blob/main/%5B%20%202%20%5D%20Tomando%20Decis%C3%B5es/C%C3%B3digo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧠 Tomando Decisões no Código

# %% [markdown]
# Imagine um programa como um caminho. Às vezes, esse caminho é uma linha reta, mas na maioria das vezes, ele tem bifurcações. O programa precisa decidir qual caminho seguir com base nas informações que recebe.
#
# Se um programa fizesse sempre a mesma coisa, poderíamos simplesmente escrever o resultado final. Mas a verdadeira força da programação está em criar códigos que se adaptam e reagem a diferentes entradas. Para dar essa "inteligência" ao nosso programa, usamos as **estruturas de seleção** `if`, `elif` e `else`.

# %% [markdown]
# # Estruturas de Seleção: `if`, `elif` e `else`

# %% [markdown]
# Pense nessas estruturas como um plano com várias etapas:
# - **`if` (Se):** É o "Plano A". O código verifica se uma condição é verdadeira. Se for, ele executa o bloco de código do `if` e ignora todo o resto.
# - **`elif` (Se não, se):** É o "Plano B", "Plano C", etc. Se o `if` (ou um `elif` anterior) for falso, o programa testa a condição do `elif`. Se for verdadeira, executa o bloco dele e para por aí.
# - **`else` (Se não):** É a opção "último caso". Se nenhuma das condições anteriores (do `if` e dos `elifs`) for verdadeira, o bloco do `else` será executado.
#
# Veja como esse fluxo funciona em Python:

# %%
condicao_1 = True
condicao_2 = True

if condicao_1:
    # Bloco de código a ser executado se a condicao_1 for verdadeira
    print("Executei o Plano A!")

elif condicao_2:
    # Bloco executado se a condicao_1 for FALSA e a condicao_2 for VERDADEIRA
    print("O Plano A falhou, então executei o Plano B!")

else:
    # Bloco executado se TODAS as condições anteriores forem falsas
    print("Nenhum plano deu certo, então executei o último caso.")

# %% [markdown]
# **⚠️ Ponto de Atenção:** Observe os dois pontos (`:`) no final de cada linha de `if`, `elif` e `else`. Eles são obrigatórios! Igualmente importante é a **indentação** (o espaço ou "tab" antes do `print`). Em Python, é a indentação que define quais comandos pertencem a cada bloco.

# %% [markdown]
# # Operadores Relacionais (Os Símbolos de Comparação)

# %% [markdown]
# Ok, mas o que são essas "condições"? Geralmente, são perguntas que resultam em True (Verdadeiro / Sim) ou False (Falso / Não).
#
# | Operador | Descrição                                                             | Exemplo                                                |
# | -------- | --------------------------------------------------------------------- | ------------------------------------------------------ |
# | `==`     | Verifica se dois valores são iguais.                                  | `1 == 1` → `True`<br><br>`0 == 1` → `False`            |
# | `!=`     | Verifica se dois valores são diferentes.                              | `0 != 1` → `True`                                      |
# | `>`      | Verifica se o valor da esquerda é maior que o valor da direita.       | `2 > 1` → `True`<br><br>**Atenção:** `2 > 2` → `False` |
# | `<`      | Verifica se o valor da esquerda é menor que o valor da direita.       | `1 < 2` → `True`                                       |
# | `>=`     | Verifica se o valor da esquerda é maior ou igual ao valor da direita. | `2 >= 2` → `True`                                      |
# | `<=`     | Verifica se o valor da esquerda é menor ou igual ao valor da direita. | `1 <= 2` → `True`                                      |
#
#
# Vamos usar isso para encontrar o maior entre dois números:

# %%
a = int(input('Digite o primeiro número: '))
b = int(input('Digite o segundo número: '))

if a >= b:
	print(f"O maior valor é o armazenado em a. {a = }")
else:
	print(f"O maior valor é o armazenado em a. {a = }")

# %% [markdown]
# #### Mão na Massa:

# %% [markdown]
# E se ao invés de dois números, quiséssemos saber o maior entre 3 números:

# %%
a = int(input('Digite o primeiro número: '))
b = int(input('Digite o segundo número: '))
c = int(input('Digite o terceiro número: '))

if a >= b:
	if a >= c:
		print(f"O maior valor é o armazenado em a. {a = }")
# Continue

# %% [markdown]
# # Operadores Lógicos: `and`, `or` e `not`

# %% [markdown]
# Viu como o código anterior começou a ficar um pouco confuso, com um `if` dentro do outro? Parece um "Haduken" de código!

# %%
if condicao1:
	if condicao2:
		if condicao3:
			if condicao4:
				print("Haduken")

# %% [markdown]
# Em vez de criar um `if` dentro de outro `if` (o que pode deixar o código confuso), podemos combinar as comparações usando operadores lógicos.
#
# | Operador | Descrição                                                                        |
# | -------- | -------------------------------------------------------------------------------- |
# | `and`    | Retorna verdadeiro se ambas as expressões condicionais forem verdadeiras.        |
# | `or`     | Retorna verdadeiro se pelo menos uma das expressões condicionais for verdadeira. |
# | `not`    | Retorna o inverso da expressão condicional. (V ➡ F, F ➡ V).                      |
#
# A "Tabela Verdade" da imagem do Bob Esponja é uma forma divertida de visualizar isso:

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - **Com `and` (e):** O Bob só fica feliz se o Patrick **E** o Lula Molusco estiverem felizes. Se um deles estiver triste, o Bob fica triste.
# - **Com `or` (ou):** O Bob fica feliz se o Patrick **OU** o Lula Molusco estiverem felizes. Ele só fica triste se os dois estiverem tristes.

# %% [markdown]
# #### Mão na Massa:

# %% [markdown]
# Agora, reescreva o desafio de encontrar o maior entre três números, mas desta vez usando os operadores lógicos para deixar o código mais simples!

# %%
if a > b and a > b:
    print(f"O maior valor é o armazenado em a. {a = }")

# %% [markdown]
# # 💪 Hora dos Exercícios!

# %% [markdown]
# ## 1. Receba a data de aniversário do usuário e a data atual e retorne quantos anos que ele tem.

# %%
# Solução:

# %% [markdown]
# ## 2. Leia um número inteiro que representa um código de DDD para discagem interurbana. Em seguida, informe a qual cidade o DDD pertence, considerando a tabela abaixo. Se a entrada for qualquer outro DDD que não esteja presente na tabela, o programa deverá informar: DDD não cadastrado!

# %%
# Solução:

# %% [markdown]
# ## 3. Crie um programa que leia um número inteiro e mostre na tela se ele é par ou ímpar.

# %%
# Solução:

# %% [markdown]
# # 🏆 Desafios (Baseados no BeeCrowd)

# %% [markdown]
# ## 1. [Teste de Seleção 1 - 1035](https://judge.beecrowd.com/pt/problems/view/1035)

# %% [markdown]
# Leia 4 valores inteiros A, B, C e D. A seguir, se B for maior do que C e se D for maior do que A, e a soma de C com D for maior que a soma de A e B e se C e D, ambos, forem positivos e se a variável A for par escrever a mensagem **"Valores aceitos"**, senão escrever **"Valores nao aceitos"**.
#
# **Entrada**
# Quatro números inteiros A, B, C e D.
#
# **Saída**
# Mostre a respectiva mensagem após a validação dos valores.
#
# | Exemplo de Entrada | Exemplo de Saída    |
# | ------------------ | ------------------- |
# | 5 6 7 8            | Valores nao aceitos |
# | 3 3 2 6            | Valores aceitos     |

# %%
# Solução:

# %% [markdown]
# ## 2. [Lanche - 1038](https://judge.beecrowd.com/pt/problems/view/1038)

# %% [markdown]
# Com base na tabela abaixo, escreva um programa que leia o código de um item e a quantidade deste item. A seguir, calcule e mostre o valor da conta a pagar.
# ![](https://resources.beecrowd.com/gallery/images/problems/UOJ_1038_pt.png)
#
# **Entrada**
# O arquivo de entrada contém dois valores inteiros correspondentes ao código e à quantidade de um item conforme tabela acima.
#
# **Saída**
# O arquivo de saída deve conter a mensagem "Total: R$ " seguido pelo valor a ser pago, com 2 casas após o ponto decimal.
#
# | Exemplo de Entrada | Exemplo de Saída |
# | ------------------ | ---------------- |
# | 3 2                | Total: R$ 10.00  |
# | 4 3                | Total: R$ 6.00   |
# | 2 3                | Total: R$ 13.50  |

# %%
# Solução:

# %% [markdown]
# ## 3. [Tipos de Triângulos - 1045](https://judge.beecrowd.com/pt/problems/view/1045)

# %% [markdown]
# Leia 3 valores de ponto flutuante A, B e C e ordene-os em ordem decrescente, de modo que o lado A representa o maior dos 3 lados. A seguir, determine o tipo de triângulo que estes três lados formam, com base nos seguintes casos, sempre escrevendo uma mensagem adequada:
# - se A ≥ B+C, apresente a mensagem: **NAO FORMA TRIANGULO**
# - se A2 = B2 + C2, apresente a mensagem: **TRIANGULO RETANGULO**
# - se A2 > B2 + C2, apresente a mensagem: **TRIANGULO OBTUSANGULO**
# - se A2 < B2 + C2, apresente a mensagem: **TRIANGULO ACUTANGULO**
# - se os três lados forem iguais, apresente a mensagem: **TRIANGULO EQUILATERO**
# - se apenas dois dos lados forem iguais, apresente a mensagem: **TRIANGULO ISOSCELES**
#
# **Entrada**
# A entrada contem três valores de ponto flutuante de dupla precisão A (0 < A) , B (0 < B) e C (0 < C).
#
# **Saída**
# Imprima todas as classificações do triângulo especificado na entrada.
#
# | Exemplos de Entrada | Exemplos de Saída                              |
# | ------------------- | ---------------------------------------------- |
# | 7.0 5.0 7.0         | TRIANGULO ACUTANGULO  <br>TRIANGULO ISOSCELES  |
# | 6.0 6.0 10.0        | TRIANGULO OBTUSANGULO  <br>TRIANGULO ISOSCELES |
# | 6.0 6.0 6.0         | TRIANGULO ACUTANGULO  <br>TRIANGULO EQUILATERO |
# | 5.0 7.0 2.0         | NAO FORMA TRIANGULO                            |
# | 6.0 8.0 10.0        | TRIANGULO RETANGULO                            |

# %%
# Solução:
