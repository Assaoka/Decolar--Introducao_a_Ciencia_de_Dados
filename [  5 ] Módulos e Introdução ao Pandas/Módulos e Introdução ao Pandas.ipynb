# %% [markdown]
# <a href="https://colab.research.google.com/github/Assaoka/Decolar--Introducao_a_Ciencia_de_Dados/blob/main/%5B%20%205%20%5D%20M%C3%B3dulos%20e%20Introdu%C3%A7%C3%A3o%20ao%20Pandas/M%C3%B3dulos%20e%20Introdu%C3%A7%C3%A3o%20ao%20Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Aula 5: O Kit do Treinador Pokémon: Capturando e Inspecionando Dados
#
# Hoje vamos dar um salto gigantesco em nossas habilidades. Vamos aprender a usar "poderes" que outros programadores criaram e a trabalhar com dados de verdade, que ficam salvos no computador!

# %% [markdown]
# ### 1. O que são Módulos (ou Bibliotecas)?
#
# Imagine que você quer construir um robô. Você não precisa inventar o parafuso, a roda ou o motor do zero, certo? Você usa peças que já existem!
#
# Na programação, é a mesma coisa. Um **módulo** (ou **biblioteca**) é um conjunto de "peças" — funções e ferramentas prontas — que outros programadores criaram e disponibilizaram para nós. Em vez de reinventar a roda, nós importamos uma biblioteca e usamos suas ferramentas.
#
# Um dos principais motivos para a popularidade do Python é a enorme quantidade de bibliotecas disponíveis para praticamente qualquer tarefa que você possa imaginar: desde análise de dados, inteligência artificial, até desenvolvimento web e jogos.
#
# Hoje, vamos usar a biblioteca mais famosa para análise de dados: o **Pandas**.

# %% [markdown]
# ### 2. O que é o Pandas?
#
# O **Pandas** é uma biblioteca focada em trabalhar com **dados tabulares** (pense em tabelas do Excel ou do Google Sheets). Ele vem com dezenas de funções prontas que nos ajudam a ler, manipular, analisar e até salvar esses dados de forma muito fácil e eficiente.
#
# Para começar a usá-lo, nosso primeiro passo é sempre o mesmo: importar a biblioteca.

# %%
# Vamos importar a biblioteca pandas e dar a ela o apelido de 'pd'
# Este é um padrão universal, todo cientista de dados faz isso!
import pandas as pd

# %% [markdown]
# ### 3. De onde vêm os dados? O formato CSV
#
# Nossos programas até agora só guardavam informações enquanto estavam rodando (na memória RAM). Se fechássemos o programa, tudo era perdido. Para trabalhar com dados de verdade, precisamos salvá-los de forma permanente (no HD).
#
# Uma das formas mais comuns de salvar dados tabulares é no formato **CSV** (_Comma-Separated Values_, ou Valores Separados por Vírgula).
#
# Abra um arquivo CSV no bloco de notas e você verá algo assim:

# %% [markdown]
# ```csv
# Name,National Dex #,Primary Typing,Secondary Typing,Secondary Typing Flag,Generation,Legendary Status,Form,Alt Form Flag,Evolution Stage,Number of Evolution,Color ID,Catch Rate,Height (dm),Weight (hg),Height (in),Weight (lbs),Base Stat Total,Health,Attack,Defense,Special Attack,Special Defense,Speed
# bulbasaur,1,grass,poison,True,generation-i,False,Base,False,1,3,green,45,7,69,28,15,318,45,49,49,65,65,45
# ivysaur,2,grass,poison,True,generation-i,False,Base,False,2,3,green,45,10,130,39,29,405,60,62,63,80,80,60
# venusaur,3,grass,poison,True,generation-i,False,Base,False,3,3,green,45,20,1000,79,220,525,80,82,83,100,100,80
# venusaur-mega,3,grass,poison,True,generation-i,True,Mega,True,3,3,green,45,24,1555,94,343,625,80,100,123,122,120,80
# charmander,4,fire,,False,generation-i,False,Base,False,1,3,red,45,6,85,24,19,309,39,52,43,60,50,65
# charmeleon,5,fire,,False,generation-i,False,Base,False,2,3,red,45,11,190,43,42,405,58,64,58,80,65,80
# charizard,6,fire,flying,True,generation-i,False,Base,False,3,3,red,45,17,905,67,200,534,78,84,78,109,85,100
# charizard-mega-x,6,fire,dragon,True,generation-i,True,Mega X,True,3,3,red,45,17,1105,67,244,634,78,130,111,130,85,100
# charizard-mega-y,6,fire,flying,True,generation-i,True,Mega Y,True,3,3,red,45,17,1005,67,222,634,78,104,78,159,115,100
# squirtle,7,water,,False,generation-i,False,Base,False,1,3,blue,45,5,90,20,20,314,44,48,65,50,64,43
# wartortle,8,water,,False,generation-i,False,Base,False,2,3,blue,45,10,225,39,50,405,59,63,80,65,80,58
# blastoise,9,water,,False,generation-i,False,Base,False,3,3,blue,45,16,855,63,188,530,79,83,100,85,105,78
# blastoise-mega,9,water,,False,generation-i,True,Mega,True,3,3,blue,45,16,1011,63,223,630,79,103,120,135,115,78
# ```

# %% [markdown]
# Cada linha é uma linha da tabela, e as vírgulas separam os valores de cada coluna. Simples, mas poderoso!
#
# O Pandas consegue ler esses arquivos e transformá-los magicamente em uma tabela superpoderosa chamada **DataFrame**.

# %%
# O Pandas lê o arquivo CSV e cria nosso DataFrame.
# Vamos usar o comando display() para visualizá-lo de forma mais bonita no Colab.
endereco = '../pokemon.csv'
df = pd.read_csv(endereco)
print(df)
# Out:
#                     Name  National Dex # Primary Typing Secondary Typing  \
# 0              bulbasaur               1          grass           poison
# 1                ivysaur               2          grass           poison
# 2               venusaur               3          grass           poison
# 3          venusaur-mega               3          grass           poison
# 4             charmander               4           fire              NaN
# ...                  ...             ...            ...              ...
# 1179          iron-crown            1023          steel          psychic
# 1180           terapagos            1024         normal              NaN
# 1181  terapagos-terastal            1024         normal              NaN
# 1182   terapagos-stellar            1024         normal              NaN
# 1183           pecharunt            1025         poison            ghost
#
#       Secondary Typing Flag     Generation  Legendary Status      Form  \
# 0                      True   generation-i             False      Base
# 1                      True   generation-i             False      Base
# 2                      True   generation-i             False      Base
# 3                      True   generation-i              True      Mega
# 4                     False   generation-i             False      Base
# ...                     ...            ...               ...       ...
# 1179                   True  generation-ix              True      Base
# 1180                  False  generation-ix              True      Base
# 1181                  False  generation-ix              True  Terastal
# 1182                  False  generation-ix              True   Stellar
# 1183                   True  generation-ix              True      Base
#
#       Alt Form Flag  Evolution Stage  ...  Weight (hg) Height (in)  \
# 0             False                1  ...           69          28
# 1             False                2  ...          130          39
# 2             False                3  ...         1000          79
# 3              True                3  ...         1555          94
# 4             False                1  ...           85          24
# ...             ...              ...  ...          ...         ...
# 1179          False                1  ...         1560          63
# 1180          False                1  ...           65           8
# 1181           True                1  ...          160          12
# 1182           True                1  ...          770          67
# 1183          False                1  ...            3          12
#
#       Weight (lbs)  Base Stat Total  Health  Attack  Defense  Special Attack  \
# 0               15              318      45      49       49              65
# 1               29              405      60      62       63              80
# 2              220              525      80      82       83             100
# 3              343              625      80     100      123             122
# 4               19              309      39      52       43              60
# ...            ...              ...     ...     ...      ...             ...
# 1179           344              590      90      72      100             122
# 1180            14              450      90      65       85              65
# 1181            35              600      95      95      110             105
# 1182           170              700     160     105      110             130
# 1183             1              600      88      88      160              88
#
#       Special Defense  Speed
# 0                  65     45
# 1                  80     60
# 2                 100     80
# 3                 120     80
# 4                  50     65
# ...               ...    ...
# 1179              108     98
# 1180               85     60
# 1181              110     85
# 1182              110     85
# 1183               88     88
#
# [1184 rows x 24 columns]

# %% [markdown]
# O comando `display()` é usado para mostrar o DataFrame de uma forma mais bonita, especialmente em ambientes como o Jupyter Notebook ou Google Colab. Ele formata a saída para que pareça uma tabela, facilitando a visualização dos dados.

# %%
display(df)
# Out:
#                     Name  National Dex # Primary Typing Secondary Typing  \
# 0              bulbasaur               1          grass           poison
# 1                ivysaur               2          grass           poison
# 2               venusaur               3          grass           poison
# 3          venusaur-mega               3          grass           poison
# 4             charmander               4           fire              NaN
# ...                  ...             ...            ...              ...
# 1179          iron-crown            1023          steel          psychic
# 1180           terapagos            1024         normal              NaN
# 1181  terapagos-terastal            1024         normal              NaN
# 1182   terapagos-stellar            1024         normal              NaN
# 1183           pecharunt            1025         poison            ghost
#
#       Secondary Typing Flag     Generation  Legendary Status      Form  \
# 0                      True   generation-i             False      Base
# 1                      True   generation-i             False      Base
# 2                      True   generation-i             False      Base
# 3                      True   generation-i              True      Mega
# 4                     False   generation-i             False      Base
# ...                     ...            ...               ...       ...
# 1179                   True  generation-ix              True      Base
# 1180                  False  generation-ix              True      Base
# 1181                  False  generation-ix              True  Terastal
# 1182                  False  generation-ix              True   Stellar
# 1183                   True  generation-ix              True      Base
#
#       Alt Form Flag  Evolution Stage  ...  Weight (hg) Height (in)  \
# 0             False                1  ...           69          28
# 1             False                2  ...          130          39
# 2             False                3  ...         1000          79
# 3              True                3  ...         1555          94
# 4             False                1  ...           85          24
# ...             ...              ...  ...          ...         ...
# 1179          False                1  ...         1560          63
# 1180          False                1  ...           65           8
# 1181           True                1  ...          160          12
# 1182           True                1  ...          770          67
# 1183          False                1  ...            3          12
#
#       Weight (lbs)  Base Stat Total  Health  Attack  Defense  Special Attack  \
# 0               15              318      45      49       49              65
# 1               29              405      60      62       63              80
# 2              220              525      80      82       83             100
# 3              343              625      80     100      123             122
# 4               19              309      39      52       43              60
# ...            ...              ...     ...     ...      ...             ...
# 1179           344              590      90      72      100             122
# 1180            14              450      90      65       85              65
# 1181            35              600      95      95      110             105
# 1182           170              700     160     105      110             130
# 1183             1              600      88      88      160              88
#
#       Special Defense  Speed
# 0                  65     45
# 1                  80     60
# 2                 100     80
# 3                 120     80
# 4                  50     65
# ...               ...    ...
# 1179              108     98
# 1180               85     60
# 1181              110     85
# 1182              110     85
# 1183               88     88
#
# [1184 rows x 24 columns]

# %% [markdown]
# ### 4. Inspeção Inicial e Manipulação de Dados
#
# Agora que a nossa Pokédex está carregada no DataFrame `df`, vamos aprender os movimentos de um verdadeiro Mestre de Dados.

# %% [markdown]
# #### 4.1. Espiando os Dados: `head`, `tail` e `sample`
# - `.head(n)`: Mostra as `n` primeiras linhas (ótimo para ver o começo).
# - `.tail(n)`: Mostra as `n` últimas linhas (ótimo para ver o final).
# - `.sample(n)`: Mostra `n` linhas aleatórias (ótimo para ter uma ideia geral).

# %%
# Vendo os 5 primeiros Pokémon
print("--- Início da Pokédex (Head) ---")
display(df.head())
# Out:
# --- Início da Pokédex (Head) ---
#             Name  National Dex # Primary Typing Secondary Typing  \
# 0      bulbasaur               1          grass           poison
# 1        ivysaur               2          grass           poison
# 2       venusaur               3          grass           poison
# 3  venusaur-mega               3          grass           poison
# 4     charmander               4           fire              NaN
#
#    Secondary Typing Flag    Generation  Legendary Status  Form  Alt Form Flag  \
# 0                   True  generation-i             False  Base          False
# 1                   True  generation-i             False  Base          False
# 2                   True  generation-i             False  Base          False
# 3                   True  generation-i              True  Mega           True
# 4                  False  generation-i             False  Base          False
#
#    Evolution Stage  ...  Weight (hg) Height (in)  Weight (lbs)  \
# 0                1  ...           69          28            15
# 1                2  ...          130          39            29
# 2                3  ...         1000          79           220
# 3                3  ...         1555          94           343
# 4                1  ...           85          24            19
#
#    Base Stat Total  Health  Attack  Defense  Special Attack  Special Defense  \
# 0              318      45      49       49              65               65
# 1              405      60      62       63              80               80
# 2              525      80      82       83             100              100
# 3              625      80     100      123             122              120
# 4              309      39      52       43              60               50
#
#    Speed
# 0     45
# 1     60
# 2     80
# 3     80
# 4     65
#
# [5 rows x 24 columns]

# %%
# Vendo os 5 últimos Pokémon
print("\n--- Final da Pokédex (Tail) ---")
display(df.tail())
# Out:
# --- Final da Pokédex (Tail) ---
#                     Name  National Dex # Primary Typing Secondary Typing  \
# 1179          iron-crown            1023          steel          psychic
# 1180           terapagos            1024         normal              NaN
# 1181  terapagos-terastal            1024         normal              NaN
# 1182   terapagos-stellar            1024         normal              NaN
# 1183           pecharunt            1025         poison            ghost
#
#       Secondary Typing Flag     Generation  Legendary Status      Form  \
# 1179                   True  generation-ix              True      Base
# 1180                  False  generation-ix              True      Base
# 1181                  False  generation-ix              True  Terastal
# 1182                  False  generation-ix              True   Stellar
# 1183                   True  generation-ix              True      Base
#
#       Alt Form Flag  Evolution Stage  ...  Weight (hg) Height (in)  \
# 1179          False                1  ...         1560          63
# 1180          False                1  ...           65           8
# 1181           True                1  ...          160          12
# 1182           True                1  ...          770          67
# 1183          False                1  ...            3          12
#
#       Weight (lbs)  Base Stat Total  Health  Attack  Defense  Special Attack  \
# 1179           344              590      90      72      100             122
# 1180            14              450      90      65       85              65
# 1181            35              600      95      95      110             105
# 1182           170              700     160     105      110             130
# 1183             1              600      88      88      160              88
#
#       Special Defense  Speed
# 1179              108     98
# 1180               85     60
# 1181              110     85
# 1182              110     85
# 1183               88     88
#
# [5 rows x 24 columns]

# %%
# Vendo 5 Pokémon aleatórios
print("\n--- Amostra Aleatória da Pokédex (Sample) ---")
display(df.sample(5))
# Out:
# --- Amostra Aleatória da Pokédex (Sample) ---
#            Name  National Dex # Primary Typing Secondary Typing  \
# 1074      pawmo             922       electric         fighting
# 837    bergmite             712            ice              NaN
# 147   lickitung             108         normal              NaN
# 279   teddiursa             216         normal              NaN
# 243      hoppip             187          grass           flying
#
#       Secondary Typing Flag     Generation  Legendary Status  Form  \
# 1074                   True  generation-ix             False  Base
# 837                   False  generation-vi             False  Base
# 147                   False   generation-i             False  Base
# 279                   False  generation-ii             False  Base
# 243                    True  generation-ii             False  Base
#
#       Alt Form Flag  Evolution Stage  ...  Weight (hg) Height (in)  \
# 1074          False                2  ...           65          16
# 837           False                1  ...          995          39
# 147           False                1  ...          655          47
# 279           False                1  ...           88          24
# 243           False                1  ...            5          16
#
#       Weight (lbs)  Base Stat Total  Health  Attack  Defense  Special Attack  \
# 1074            14              350      60      75       40              50
# 837            219              304      55      69       85              32
# 147            144              385      90      55       75              60
# 279             19              330      60      80       50              50
# 243              1              250      35      35       40              35
#
#       Special Defense  Speed
# 1074               40     85
# 837                35     28
# 147                75     30
# 279                50     40
# 243                55     50
#
# [5 rows x 24 columns]

# %% [markdown]
# #### 4.2. Informações Técnicas: `info` e `shape`
# - `.shape`: Nos diz as dimensões da tabela (linhas, colunas).
# - `.info()`: Nos dá um raio-x completo, incluindo o tipo de dado de cada coluna e o uso de memória (muito útil para ver se há dados faltando!).

# %%
# Mostra uma tupla com (número_de_linhas, número_de_colunas)
print(f"Nossa Pokédex tem {df.shape[0]} Pokémon e {df.shape[1]} atributos.")
# Out:
# Nossa Pokédex tem 1184 Pokémon e 24 atributos.

# %%
# Exibe o resumo técnico. memory_usage='deep' nos dá um cálculo de memória mais preciso.
print("\n--- Raio-X da Pokédex (Info) ---")
df.info(memory_usage="deep")
# Out:
# --- Raio-X da Pokédex (Info) ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1184 entries, 0 to 1183
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Name                   1184 non-null   object
#  1   National Dex #         1184 non-null   int64
#  2   Primary Typing         1184 non-null   object
#  3   Secondary Typing       654 non-null    object
#  4   Secondary Typing Flag  1184 non-null   bool
#  5   Generation             1184 non-null   object
#  6   Legendary Status       1184 non-null   bool
#  7   Form                   1184 non-null   object
#  8   Alt Form Flag          1184 non-null   bool
#  9   Evolution Stage        1184 non-null   int64
#  10  Number of Evolution    1184 non-null   int64
#  11  Color ID               1184 non-null   object
#  12  Catch Rate             1184 non-null   int64
#  13  Height (dm)            1184 non-null   int64
#  14  Weight (hg)            1184 non-null   int64
#  15  Height (in)            1184 non-null   int64
#  16  Weight (lbs)           1184 non-null   int64
#  17  Base Stat Total        1184 non-null   int64
#  18  Health                 1184 non-null   int64
#  19  Attack                 1184 non-null   int64
#  20  Defense                1184 non-null   int64
#  21  Special Attack         1184 non-null   int64
#  22  Special Defense        1184 non-null   int64
#  23  Speed                  1184 non-null   int64
# dtypes: bool(3), int64(15), object(6)
# memory usage: 518.7 KB

# %% [markdown]
# #### 4.3. Selecionando e Operando com Colunas
# Podemos pegar colunas específicas para focar nossa análise e até fazer operações matemáticas com elas!

# %%
# Selecionando uma coluna
df['Name']
# Out:
# 0                bulbasaur
# 1                  ivysaur
# 2                 venusaur
# 3            venusaur-mega
# 4               charmander
#                ...
# 1179            iron-crown
# 1180             terapagos
# 1181    terapagos-terastal
# 1182     terapagos-stellar
# 1183             pecharunt
# Name: Name, Length: 1184, dtype: object

# %%
# Selecionando múltiplas colunas
stats_essenciais = df[['Name', 'Attack', 'Defense', 'Speed']]
print("--- Stats Essenciais ---")
stats_essenciais.head()
# Out:
# --- Stats Essenciais ---
#             Name  Attack  Defense  Speed
# 0      bulbasaur      49       49     45
# 1        ivysaur      62       63     60
# 2       venusaur      82       83     80
# 3  venusaur-mega     100      123     80
# 4     charmander      52       43     65

# %%
# Podemos criar uma nova coluna! Que tal um 'Total Power' somando Ataque e Defesa?
df['Total Power'] = df['Attack'] + df['Defense'] + df['Speed']
print("\n--- Criamos a coluna 'Total Power' ---")
df[['Name', 'Attack', 'Defense', 'Speed', 'Total Power']].head()
# Out:
# --- Criamos a coluna 'Total Power' ---
#             Name  Attack  Defense  Speed  Total Power
# 0      bulbasaur      49       49     45          143
# 1        ivysaur      62       63     60          185
# 2       venusaur      82       83     80          245
# 3  venusaur-mega     100      123     80          303
# 4     charmander      52       43     65          160

# %% [markdown]
# #### 4.4. Filtrando: A Arte de Fazer Perguntas
#
# E se quisermos encontrar apenas os Pokémon do tipo 'Fire'? Ou os que são da Geração I? Para isso, usamos **filtros**. A sintaxe é: `df[ <condição> ]`.

# %%
# Encontrando todos os Pokémon do tipo Fogo
df_fogo = df[df['Primary Typing'] == 'fire']
print("--- Apenas Pokémon do tipo Fogo ---")
df_fogo.head()
# Out:
# --- Apenas Pokémon do tipo Fogo ---
#                Name  National Dex # Primary Typing Secondary Typing  \
# 4        charmander               4           fire              NaN
# 5        charmeleon               5           fire              NaN
# 6         charizard               6           fire           flying
# 7  charizard-mega-x               6           fire           dragon
# 8  charizard-mega-y               6           fire           flying
#
#    Secondary Typing Flag    Generation  Legendary Status    Form  \
# 4                  False  generation-i             False    Base
# 5                  False  generation-i             False    Base
# 6                   True  generation-i             False    Base
# 7                   True  generation-i              True  Mega X
# 8                   True  generation-i              True  Mega Y
#
#    Alt Form Flag  Evolution Stage  ...  Height (in) Weight (lbs)  \
# 4          False                1  ...           24           19
# 5          False                2  ...           43           42
# 6          False                3  ...           67          200
# 7           True                3  ...           67          244
# 8           True                3  ...           67          222
#
#    Base Stat Total  Health  Attack  Defense  Special Attack  Special Defense  \
# 4              309      39      52       43              60               50
# 5              405      58      64       58              80               65
# 6              534      78      84       78             109               85
# 7              634      78     130      111             130               85
# 8              634      78     104       78             159              115
#
#    Speed  Total Power
# 4     65          160
# 5     80          202
# 6    100          262
# 7    100          341
# 8    100          282
#
# [5 rows x 25 columns]

# %%
# Encontrando Pokémon com Ataque maior que 150
df_super_ataque = df[df['Attack'] > 150]
print("\n--- Apenas Pokémon com Ataque SUPERIOR a 150 ---")
df_super_ataque
# Out:
# --- Apenas Pokémon com Ataque SUPERIOR a 150 ---
#                       Name  National Dex # Primary Typing Secondary Typing  \
# 170            pinsir-mega             127            bug           flying
# 177          gyarados-mega             130          water             dark
# 203          mewtwo-mega-x             150        psychic         fighting
# 276         heracross-mega             214            bug         fighting
# 314         tyranitar-mega             248           rock             dark
# 325          blaziken-mega             257           fire         fighting
# 361                slaking             289         normal              NaN
# 438           banette-mega             354          ghost              NaN
# 475         groudon-primal             383         ground             fire
# 477          rayquaza-mega             384         dragon           flying
# 502              rampardos             409           rock              NaN
# 542          garchomp-mega             445         dragon           ground
# 575           gallade-mega             475        psychic         fighting
# 591              regigigas             486         normal              NaN
# 668   darmanitan-galar-zen             555            ice             fire
# 765           kyurem-black             646         dragon              ice
# 849           diancie-mega             719           rock            fairy
# 851          hoopa-unbound             720        psychic             dark
# 941                kartana             798          grass            steel
# 944          necrozma-dusk             800        psychic            steel
# 946         necrozma-ultra             800        psychic           dragon
# 1048           calyrex-ice             898        psychic              ice
# 1117          palafin-hero             964          water              NaN
#
#       Secondary Typing Flag       Generation  Legendary Status      Form  \
# 170                    True     generation-i              True      Mega
# 177                    True     generation-i              True      Mega
# 203                    True     generation-i              True    Mega X
# 276                    True    generation-ii              True      Mega
# 314                    True    generation-ii              True      Mega
# 325                    True   generation-iii              True      Mega
# 361                   False   generation-iii             False      Base
# 438                   False   generation-iii              True      Mega
# 475                    True   generation-iii              True    Primal
# 477                    True   generation-iii              True      Mega
# 502                   False    generation-iv             False      Base
# 542                    True    generation-iv              True      Mega
# 575                    True    generation-iv              True      Mega
# 591                   False    generation-iv              True      Base
# 668                    True     generation-v             False  Galarian
# 765                    True     generation-v              True     Black
# 849                    True    generation-vi              True      Mega
# 851                    True    generation-vi              True   Unbound
# 941                    True   generation-vii              True      Base
# 944                    True   generation-vii              True      Dusk
# 946                    True   generation-vii              True     Ultra
# 1048                   True  generation-viii              True       Ice
# 1117                  False    generation-ix             False      Hero
#
#       Alt Form Flag  Evolution Stage  ...  Height (in) Weight (lbs)  \
# 170            True                1  ...           67          130
# 177            True                2  ...          256          672
# 203            True                1  ...           91          280
# 276            True                1  ...           67          138
# 314            True                3  ...           98          562
# 325            True                3  ...           75          115
# 361           False                3  ...           79          288
# 438            True                2  ...           47           29
# 475            True                1  ...          197         2204
# 477            True                1  ...          425          864
# 502           False                2  ...           63          226
# 542            True                3  ...           75          209
# 575            True                3  ...           63          124
# 591           False                1  ...          146          926
# 668            True                2  ...           67          265
# 765            True                1  ...          130          717
# 849            True                1  ...           43           61
# 851            True                1  ...          256         1080
# 941           False                1  ...           12            0
# 944            True                1  ...          150         1014
# 946            True                1  ...          295          507
# 1048           True                1  ...           94         1784
# 1117           True                2  ...           71          215
#
#       Base Stat Total  Health  Attack  Defense  Special Attack  \
# 170               600      65     155      120              65
# 177               640      95     155      109              70
# 203               780     106     190      100             154
# 276               600      80     185      115              40
# 314               700     100     164      150              95
# 325               630      80     160       80             130
# 361               670     150     160      100              95
# 438               555      64     165       75              93
# 475               770     100     180      160             150
# 477               780     105     180      100             180
# 502               495      97     165       60              65
# 542               700     108     170      115             120
# 575               618      68     165       95              65
# 591               670     110     160      110              80
# 668               540     105     160       55              30
# 765               700     125     170      100             120
# 849               700      50     160      110             160
# 851               680      80     160       60             170
# 941               570      59     181      131              59
# 944               680      97     157      127             113
# 946               754      97     167       97             167
# 1048              680     100     165      150              85
# 1117              650     100     160       97             106
#
#       Special Defense  Speed  Total Power
# 170                90    105          380
# 177               130     81          345
# 203               100    130          420
# 276               105     75          375
# 314               120     71          385
# 325                80    100          340
# 361                65    100          360
# 438                83     75          315
# 475                90     90          430
# 477               100    115          395
# 502                50     58          283
# 542                95     92          377
# 575               115    110          370
# 591               110    100          370
# 668                55    135          350
# 765                90     95          365
# 849               110    110          380
# 851               130     80          300
# 941                31    109          421
# 944               109     77          361
# 946                97    129          393
# 1048              130     50          365
# 1117               87    100          357
#
# [23 rows x 25 columns]

# %% [markdown]
# #### 4.5. Ordenando: Quem é o mais forte?
#
# Depois de filtrar, muitas vezes queremos ordenar os resultados. Usamos `.sort_values()`.

# %%
# Pegando os Pokémon de Fogo e ordenando pelo Ataque, do maior para o menor
df_fogo_mais_forte = df_fogo.sort_values(by='Attack', ascending=False)
print("--- Top 5 Pokémon de Fogo, ordenados pelo Ataque ---")
display(df_fogo_mais_forte.head())
# Out:
# --- Top 5 Pokémon de Fogo, ordenados pelo Ataque ---
#                     Name  National Dex # Primary Typing Secondary Typing  \
# 325        blaziken-mega             257           fire         fighting
# 665  darmanitan-standard             555           fire              NaN
# 316                ho-oh             250           fire           flying
# 7       charizard-mega-x               6           fire           dragon
# 184              flareon             136           fire              NaN
#
#      Secondary Typing Flag      Generation  Legendary Status    Form  \
# 325                   True  generation-iii              True    Mega
# 665                  False    generation-v             False    Base
# 316                   True   generation-ii              True    Base
# 7                     True    generation-i              True  Mega X
# 184                  False    generation-i             False    Base
#
#      Alt Form Flag  Evolution Stage  ...  Height (in) Weight (lbs)  \
# 325           True                3  ...           75          115
# 665          False                2  ...           51          205
# 316          False                1  ...          150          439
# 7             True                3  ...           67          244
# 184          False                2  ...           35           55
#
#      Base Stat Total  Health  Attack  Defense  Special Attack  \
# 325              630      80     160       80             130
# 665              480     105     140       55              30
# 316              680     106     130       90             110
# 7                634      78     130      111             130
# 184              525      65     130       60              95
#
#      Special Defense  Speed  Total Power
# 325               80    100          340
# 665               55     95          290
# 316              154     90          310
# 7                 85    100          341
# 184              110     65          255
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 5. Hora dos Exercícios!
#
# Vamos praticar esses novos movimentos.

# %% [markdown]
# **1. Os Iniciais da Geração 1:** Crie um DataFrame que contenha apenas Bulbasaur, Charmander e Squirtle.

# %% [markdown]
# **2. O Pokémon mais Rápido:** Encontre o Pokémon com o maior valor de `Speed` em todo o dataset.

# %% [markdown]
# **3. Pesos Pesados:** Encontre todos os Pokémon que pesam (coluna `Weight (hg)`) mais de 70 kg.
#
# Obs: 1 kg = 10 hg.

# %% [markdown]
# **4. Fraqueza Psíquica:** Encontre todos os Pokémon do tipo `Bug` que sejam da `generation-i`.

# %% [markdown]
# **5. Top 5 Defensores:** Crie um DataFrame com os 5 Pokémon com a maior `Defense`.

# %% [markdown]
# **6. Elite Lendária:** Crie um DataFrame com todos os Pokémon lendários (`Legendary Status` igual a `True`), ordene-os pelo `Base Stat Total` (do maior para o menor) e salve esse DataFrame em um novo arquivo CSV chamado `legendary_pokemon.csv`.
